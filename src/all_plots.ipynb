# %% [markdown]
# # All Plots
#
# This notebook generates and displays all plots from the repo.

# %%
# Generate plots
import os
import sys

repo_root = r"C:\Users\Alex\Optical-Analogues-to-Kerr-Newman-Black-Holes"
src_dir = os.path.join(repo_root, 'src')
if src_dir not in sys.path:
    sys.path.insert(0, src_dir)

from plots_profiles import (
    make_schwarzschild_profiles,
    make_kerr_newman_profiles,
)

make_schwarzschild_profiles()
make_kerr_newman_profiles()
# Out:
# C:\Users\Alex\Optical-Analogues-to-Kerr-Newman-Black-Holes\src\Kerr_Newman.py:67: RuntimeWarning: invalid value encountered in divide
#   out = numerator / denom
# C:\Users\Alex\Optical-Analogues-to-Kerr-Newman-Black-Holes\src\Kerr_Newman.py:89: RuntimeWarning: invalid value encountered in divide
#   val = (pp**2 * Xp) / np.sqrt(Rp)

# %%
# Display plots
from IPython.display import Image, display

plot_dir = os.path.join(repo_root, 'results', 'profiles')
plots = [
    'schwarzschild_step_profiles.png',
    'schwarzschild_continuous_profiles.png',
    'kerr_newman_profiles.png',
]

for name in plots:
    path = os.path.join(plot_dir, name)
    if os.path.exists(path):
        display(Image(filename=path))
    else:
        print(f'Missing: {path}')
